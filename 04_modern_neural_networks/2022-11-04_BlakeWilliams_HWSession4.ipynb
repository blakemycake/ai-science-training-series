# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("S4_loss_accuracy.csv")
print(df.head())
# Out:
#    step     loss  accuracy
# 0     1  179.055     0.000
# 1     2  115.664     0.000
# 2     3   60.563     0.000
# 3     4   35.750     0.000
# 4     5   22.762     0.008

# %%
df.plot(x='step',y='loss',style='.')
# Out:
# <AxesSubplot:xlabel='step'>

# %%
df.plot(x='step',y='accuracy',style='.')
# Out:
# <AxesSubplot:xlabel='step'>
